# %%
# Selinium
# beautiful soap
#
#

# %%
open??

# %%
open('abc1.txt')
# Out:
# <_io.TextIOWrapper name='abc1.txt' mode='r' encoding='UTF-8'>

# %%
d =open('abc1.txt')
print(list(d))
d.close()
# Out:
# ['Line1\n', 'Line2\n', 'Line3\n', 'Line4\n', 'Line5\n', 'Line6\n', 'Line7\n', 'Line8\n', 'Line9\n', 'Line10\n']

# %%
# with open file as <variable>

with open('abc1.txt') as myfile:
    content = myfile.readlines()
    print(type(content))
    print(content)
# Out:
# <class 'list'>
# ['Line1\n', 'Line2\n', 'Line3\n', 'Line4\n', 'Line5\n', 'Line6\n', 'Line7\n', 'Line8\n', 'Line9\n', 'Line10\n']

# %%
# with open file as <variable>

with open('abc1.txt') as myfile:
    content = myfile.readlines()[:3]
    myfile.write('Pakistan Zindabad')
    print(type(content))
    print(content)
# Out:
# ---------------------------------------------------------------------------
# UnsupportedOperation                      Traceback (most recent call last)
# <ipython-input-15-35fd38b408ba> in <module>
#       3 with open('abc1.txt') as myfile:
#       4     content = myfile.readlines()[:3]
# ----> 5     myfile.write('Pakistan Zindabad')
#       6     print(type(content))
#       7     print(content)
#
# UnsupportedOperation: not writable

# %%
with open('abc2.txt' , mode='w') as f:
    content = f.readlines()
    print(content)
# Out:
# ---------------------------------------------------------------------------
# UnsupportedOperation                      Traceback (most recent call last)
# <ipython-input-16-78082753a7a7> in <module>
#       1 with open('abc2.txt' , mode='w') as f:
# ----> 2     content = f.readlines()
#       3     print(content)
#
# UnsupportedOperation: not readable

# %%
with open('abc2.txt' , mode='w') as f:
    f.write('Pakistan Zindabad')

# %%
with open('abc2.txt' , mode='w') as f:
    f.write('Pakistan Paindabad')

# %%
with open('abc.txt', 'a') as f:
    f.write("Come Tesla again")

# %%
with open('abc4.txt' , mode = 'a+') as f:
    f.write('Running on second time')
    f.seek(0)
    c = f.readlines()
    print(c)
# Out:
# ['Please mujhay maaf ker doRunning on second time']

# %%
# %pwd
# Out:
# '/media/talhajavaidmalik/DATA/PIAIC/Python basics/Python-Basics-PIAIC-/Class 14'

# %%
[1,2,3]

[A, B, C]

[C.B,A , 3,2,1]

# %%
list1 = [1,2,3]
with open('abc2.txt' , mode='w') as f:
    for i in list1:
        f.write(str(i))

# %%
list2 = ['A','B','C']
with open('abc2.txt' , mode = 'a+') as f:
    for i in list2:
        f.write(str(i))
        f.seek(0)
        c = f.readlines()

# %%
with open('abc2.txt', mode = 'r') as f:
        content = f.readline()
        print(content)
# Out:
# 123ABC

# %%
with open('abc2.txt' , mode = )

# %%
#TASK

with open('abc5.txt' , 'w+') as f:
    a = list(reversed(f.readlines()))
    b = list(reversed(['A', 'B' , 'C']))
    c = str(a+b)
    d = "".join(c)
    f.seek(0)
    f.write(d)

# %%
open('abc6.txt', 'x')
# Out:
# <_io.TextIOWrapper name='abc6.txt' mode='x' encoding='UTF-8'>

# %%
open??

# %%
# %load a.py
import numpy as np
import cv2

cap = cv2.VideoCapture(0)

while(True):
    ret, frame = cap.read()
    gray =

# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt

img = mpimg.imread("./andrew.jpeg")
print(img.shape)
plt.imshow(img)
# Out:
# (494, 740, 3)

# %%
#pip install opencvpython

import cv2
image

# %%
from PIL import Image
